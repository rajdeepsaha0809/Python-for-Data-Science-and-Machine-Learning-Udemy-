# %%
import numpy as np
import pandas as pd

# %%
from numpy.random import randn

# %%
np.random.seed(101)

# %%
df=pd.DataFrame(randn(5,4),['A','B','C','D','E'],['W','X','Y','Z'])

# %%
df
# Out:
#           W         X         Y         Z
# A  0.390528  0.146639  1.269122  0.307881
# B -0.606806  0.919318 -1.196118  0.508945
# C -0.848440  2.010793 -0.137610 -0.598269
# D  0.028234  0.392746 -1.441695  0.000323
# E -1.049912 -0.229937 -1.283599 -2.711192

# %%
df['W']
# Out:
# A    0.390528
# B   -0.606806
# C   -0.848440
# D    0.028234
# E   -1.049912
# Name: W, dtype: float64

# %%
df[['W','Z']]
# Out:
#           W         Z
# A  0.390528  0.307881
# B -0.606806  0.508945
# C -0.848440 -0.598269
# D  0.028234  0.000323
# E -1.049912 -2.711192

# %%
df['new']=df['W']+df['Y']

# %%
df
# Out:
#           W         X         Y         Z       new
# A  0.390528  0.146639  1.269122  0.307881  1.659650
# B -0.606806  0.919318 -1.196118  0.508945 -1.802924
# C -0.848440  2.010793 -0.137610 -0.598269 -0.986050
# D  0.028234  0.392746 -1.441695  0.000323 -1.413462
# E -1.049912 -0.229937 -1.283599 -2.711192 -2.333511

# %%
df.drop('new',axis=1)
# Out:
#           W         X         Y         Z
# A  0.390528  0.146639  1.269122  0.307881
# B -0.606806  0.919318 -1.196118  0.508945
# C -0.848440  2.010793 -0.137610 -0.598269
# D  0.028234  0.392746 -1.441695  0.000323
# E -1.049912 -0.229937 -1.283599 -2.711192

# %%
df
# Out:
#           W         X         Y         Z       new
# A  0.390528  0.146639  1.269122  0.307881  1.659650
# B -0.606806  0.919318 -1.196118  0.508945 -1.802924
# C -0.848440  2.010793 -0.137610 -0.598269 -0.986050
# D  0.028234  0.392746 -1.441695  0.000323 -1.413462
# E -1.049912 -0.229937 -1.283599 -2.711192 -2.333511

# %%
df.drop('new',axis=1,inplace=True)

# %%
df
# Out:
#           W         X         Y         Z
# A  0.390528  0.146639  1.269122  0.307881
# B -0.606806  0.919318 -1.196118  0.508945
# C -0.848440  2.010793 -0.137610 -0.598269
# D  0.028234  0.392746 -1.441695  0.000323
# E -1.049912 -0.229937 -1.283599 -2.711192

# %%
df.drop('E',axis=0)
# Out:
#           W         X         Y         Z
# A  0.390528  0.146639  1.269122  0.307881
# B -0.606806  0.919318 -1.196118  0.508945
# C -0.848440  2.010793 -0.137610 -0.598269
# D  0.028234  0.392746 -1.441695  0.000323

# %%
df.shape
# Out:
# (5, 4)

# %%
df.loc['A']
# Out:
# W    0.390528
# X    0.146639
# Y    1.269122
# Z    0.307881
# Name: A, dtype: float64

# %%
df.loc[['A','C']]
# Out:
#           W         X         Y         Z
# A  0.390528  0.146639  1.269122  0.307881
# C -0.848440  2.010793 -0.137610 -0.598269

# %%
df.iloc[0]
# Out:
# W    0.390528
# X    0.146639
# Y    1.269122
# Z    0.307881
# Name: A, dtype: float64

# %%
df.iloc[[0,2]]
# Out:
#           W         X         Y         Z
# A  0.390528  0.146639  1.269122  0.307881
# C -0.848440  2.010793 -0.137610 -0.598269

# %%
df.loc['A','Y']
# Out:
# 1.2691217815776354

# %%
df.iloc[2:,:3]
# Out:
#           W         X         Y
# C -0.848440  2.010793 -0.137610
# D  0.028234  0.392746 -1.441695
# E -1.049912 -0.229937 -1.283599
