# %% [markdown]
# ### Basic Calculations

# %%
1+1
# Out:
# 2

# %%
2*8
# Out:
# 16

# %%
8/3
# Out:
# 2.6666666666666665

# %%
round(8/3,2)
# Out:
# 2.67

# %%
8%5 #only remainder
# Out:
# 3

# %%
8//5 #only quotient
# Out:
# 1

# %%
var=2 #assignment
var**5
# Out:
# 32

# %% [markdown]
# ### String

# %%
'String Calculation' #can use single or double quotes
# Out:
# 'String Calculation'

# %%
'String'+'Calculation'
# Out:
# 'StringCalculation'

# %%
x='hello'
x
# Out:
# 'hello'

# %%
print(x) #get rid of quote in output
# Out:
# hello

# %%
#formatting
name= 'Rajdeep'
birth= 1999
'my name is {} and my year of birth is {}'.format(name,birth)
# Out:
# 'my name is Rajdeep and my year of birth is 1999'

# %%
s='abcdefgh'
print(s[0])
print(s[2:5]) #extracts 3rd to 5th element
print(s[2:]) #extracts 3rd to all
print(s[:4]) #select first 4 elements
# Out:
# a
# cde
# cdefgh
# abcd

# %% [markdown]
# ### List

# %%
[1,2,3]
# Out:
# [1, 2, 3]

# %%
my_list=[1,2,3]

# %%
[1,2,3,'a',True]
# Out:
# [1, 2, 3, 'a', True]

# %%
my_list.append(4)

# %%
my_list
# Out:
# [1, 2, 3, 4]

# %%
my_list=['a','b','c']
my_list
# Out:
# ['a', 'b', 'c']

# %%
my_list.append('d')

# %%
my_list
# Out:
# ['a', 'b', 'c', 'd']

# %%
my_list[2]
# Out:
# 'c'

# %%
my_list[0]='A'

# %%
my_list
# Out:
# ['A', 'b', 'c', 'd']

# %%
nest=[1,2,3,[4,5,6]]
nest[3][1]
# Out:
# 5
