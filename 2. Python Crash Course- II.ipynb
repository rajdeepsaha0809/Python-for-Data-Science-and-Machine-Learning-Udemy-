# %% [markdown]
# ### Dictionaries, Tuple, Logical Statement

# %%
d={'key1':'value1','key2':123}
d

# %%
d['key2']
# Out:
# 123

# %%
d={'k1':[1,2,3]}
d
# Out:
# {'k1': [1, 2, 3]}

# %%
d= {'k1':{'innerkey':[1,2,3]}}
d['k1']['innerkey'][1]
# Out:
# 2

# %%
t= (1,2,3) #tuple (non- changable)
l= [1,2,3] #list (changable)

# %%
print(t[0])
print(l[1])
# Out:
# 1
# 2

# %%
# t[0]=4 #can't be done
l[0]=4
print(l)
# Out:
# [4, 2, 3]

# %%
s={1,1,1,2,2,2,3,3,3,4,4,4,5,5,5} #set
s
# Out:
# {1, 2, 3, 4, 5}

# %%
s.add(6)
s
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
1<2 and 2<3
# Out:
# True

# %%
1<2 and 2>3
# Out:
# False

# %%
1<2 or 2>3
# Out:
# True

# %% [markdown]
# ### Conditional Statement

# %%
if 1<2:
    print('ok')
# Out:
# ok

# %%
if 1<2:
    print('First')
else:
    print('last')
# Out:
# First

# %%
x=5
if x%2==0:
    print(x**2)
elif x%3==0:
    print(x**3)
else:
    print(x**4)
# Out:
# 625
