# %%
import numpy as np
import pandas as pd

# %%
d={'A':[1,2,np.nan,3],'B':[1,np.nan,np.nan,2],'C':[np.nan,np.nan,np.nan,5],'D':[1,2,3,4]}
df=pd.DataFrame(d)

# %%
df
# Out:
#      A    B    C  D
# 0  1.0  1.0  NaN  1
# 1  2.0  NaN  NaN  2
# 2  NaN  NaN  NaN  3
# 3  3.0  2.0  5.0  4

# %%
df.dropna()
# Out:
#      A    B    C  D
# 3  3.0  2.0  5.0  4

# %%
df.dropna(axis=1)
# Out:
#    D
# 0  1
# 1  2
# 2  3
# 3  4

# %%
df.dropna(thresh=2)
# Out:
#      A    B    C  D
# 0  1.0  1.0  NaN  1
# 1  2.0  NaN  NaN  2
# 3  3.0  2.0  5.0  4

# %%
df.dropna(thresh=2,axis=1)
# Out:
#      A    B  D
# 0  1.0  1.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3
# 3  3.0  2.0  4

# %%
df.fillna('FILL_VALUE')
# Out:
#             A           B           C  D
# 0         1.0         1.0  FILL_VALUE  1
# 1         2.0  FILL_VALUE  FILL_VALUE  2
# 2  FILL_VALUE  FILL_VALUE  FILL_VALUE  3
# 3         3.0         2.0         5.0  4

# %%
df['A'].fillna(value=df['A'].mean())
# Out:
# 0    1.0
# 1    2.0
# 2    2.0
# 3    3.0
# Name: A, dtype: float64
