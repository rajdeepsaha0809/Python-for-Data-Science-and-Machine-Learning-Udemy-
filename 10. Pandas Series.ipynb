# %%
#!pip install pandas

# %%
import numpy as np
import pandas as pd

# %%
labels=['a','b','c']
my_data=np.array([10,20,30])
d={'aA':10,'bB':20,'cC':30}

# %%
pd.Series(data=my_data)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int32

# %%
series=pd.Series(data=my_data,index=labels)
series
# Out:
# a    10
# b    20
# c    30
# dtype: int32

# %%
series['a']
# Out:
# 10

# %%
pd.Series(d)
# Out:
# aA    10
# bB    20
# cC    30
# dtype: int64

# %%
ser1=pd.Series(['Kohli','Rohit','Rahul'],['RCB','MI','LSG'])
ser1
# Out:
# RCB    Kohli
# MI     Rohit
# LSG    Rahul
# dtype: object

# %%
print(ser1['MI'])
# Out:
# Rohit

# %%
ser3=pd.Series([1,2,3,4],['a','b','c','d'])
ser4=pd.Series([4,3,5,2],['d','c','e','b'])

# %%
ser3
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
ser4
# Out:
# d    4
# c    3
# e    5
# b    2
# dtype: int64

# %%
ser3+ser4
# Out:
# a    NaN
# b    4.0
# c    6.0
# d    8.0
# e    NaN
# dtype: float64
